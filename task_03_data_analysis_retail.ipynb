# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    "https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view")
df.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="ofCYYHCJcodlb83B38RURQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>SampleSuperstore.csv - Google Drive</title><meta property="og:title" content="SampleSuperstore.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view?usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                               try{
# 1                                                 /*
# 2             Copyright The Closure Library Authors.
# 3                SPDX-License-Identifier: Apache-2.0
# 4                                                 */
#
#    400  500  \
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
#
#   700" nonce="ofCYYHCJcodlb83B38RURQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.mah7ylA7ZOg.L.X.O/am=aA/d=0/rs=AO0039uvbN3GAEzK72W3UF203KIk9l39PA" nonce="ofCYYHCJcodlb83B38RURQ"><script nonce="75Sin2ZoQ4CmtvXrHc5giA">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd" docs-shdn:0 docs-tfh:""  \
# 0                  NaN                     NaN         NaN         NaN
# 1                  NaN                     NaN         NaN         NaN
# 2                  NaN                     NaN         NaN         NaN
# 3                  NaN                     NaN         NaN         NaN
# 4                  NaN                     NaN         NaN         NaN
#
#   info_params:{} docos-eddmh:false  ... null.178 null.179  \
# 0            NaN               NaN  ...      NaN      NaN
# 1            NaN               NaN  ...      NaN      NaN
# 2            NaN               NaN  ...      NaN      NaN
# 3            NaN               NaN  ...      NaN      NaN
# 4            NaN               NaN  ...      NaN      NaN
#
#   d7IcYbP-FsWGsAXr4bb4Bg.1 0.71 0].8 [[null.1 null.180 null.181  \
# 0                      NaN  NaN  NaN      NaN      NaN      NaN
# 1                      NaN  NaN  NaN      NaN      NaN      NaN
# 2                      NaN  NaN  NaN      NaN      NaN      NaN
# 3                      NaN  NaN  NaN      NaN      NaN      NaN
# 4                      NaN  NaN  NaN      NaN      NaN      NaN
#
#   https://www.gstatic.com/og/_/js/k=og.qtm.en_US.38L9F6mYc1U.O/rt=j/m=qabr,q_d,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTsOqmng0D__mtPtmMyv2hH_VU6AQw]]]]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 709 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Columns: 709 entries, <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="vCLuJ6ZFNDI0pOFwpIx1Mg">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>SampleSuperstore.csv - Google Drive</title><meta property="og:title" content="SampleSuperstore.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view?usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300 to };this.gbar_=this.gbar_||{};(function(_){var window=this;
# dtypes: float64(415), object(294)
# memory usage: 958.4+ KB
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="vCLuJ6ZFNDI0pOFwpIx1Mg">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>SampleSuperstore.csv - Google Drive</title><meta property="og:title" content="SampleSuperstore.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view?usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                               try{
# 1                                                 /*
# 2             Copyright The Closure Library Authors.
# 3                SPDX-License-Identifier: Apache-2.0
# 4                                                 */
#
#    400  500  \
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
#
#   700" nonce="vCLuJ6ZFNDI0pOFwpIx1Mg"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.mah7ylA7ZOg.L.X.O/am=aA/d=0/rs=AO0039uvbN3GAEzK72W3UF203KIk9l39PA" nonce="vCLuJ6ZFNDI0pOFwpIx1Mg"><script nonce="YccGidJ0DOCdxsPjqWRWTg">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd" docs-shdn:0 docs-tfh:""  \
# 0                  NaN                     NaN         NaN         NaN
# 1                  NaN                     NaN         NaN         NaN
# 2                  NaN                     NaN         NaN         NaN
# 3                  NaN                     NaN         NaN         NaN
# 4                  NaN                     NaN         NaN         NaN
#
#   info_params:{} docos-eddmh:false  ... null.178 null.179  \
# 0            NaN               NaN  ...      NaN      NaN
# 1            NaN               NaN  ...      NaN      NaN
# 2            NaN               NaN  ...      NaN      NaN
# 3            NaN               NaN  ...      NaN      NaN
# 4            NaN               NaN  ...      NaN      NaN
#
#   UbIcYaOPCI3QtAWD9am4Bw.1 0.71 0].8 [[null.1 null.180 null.181  \
# 0                      NaN  NaN  NaN      NaN      NaN      NaN
# 1                      NaN  NaN  NaN      NaN      NaN      NaN
# 2                      NaN  NaN  NaN      NaN      NaN      NaN
# 3                      NaN  NaN  NaN      NaN      NaN      NaN
# 4                      NaN  NaN  NaN      NaN      NaN      NaN
#
#   https://www.gstatic.com/og/_/js/k=og.qtm.en_US.38L9F6mYc1U.O/rt=j/m=qabr,q_d,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTsOqmng0D__mtPtmMyv2hH_VU6AQw]]]]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 709 columns]

# %%
df.isnull().sum()
